# %%
from tkinter import Tk
from tkinter import filedialog as fd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.cm import viridis

from functions import *

# %%
messages = process_transcript_to_pandas()

# %%
# Assuming you have a DataFrame named 'messages'
all_messages = ' '.join(messages['contents'].astype(str).str.lower())

# Split the text into words
words = all_messages.split()

# Create a DataFrame with word counts
word_counts = pd.Series(words).value_counts().reset_index()
word_counts.columns = ['word', 'count']

word_counts.set_index('word', inplace=True)

word_counts = word_counts.drop(['omitted>', '<media', 'null', 'message'])

word_counts.reset_index()

# Display the top 20 most common words
top_words = word_counts.head(20)
print(top_words)
# Out:
#       count
# word
# je     3189
# i      2643
# da     2355
# to     1828
# ne     1727
# sam    1567
# se     1549
# u      1470
# ja     1373
# a      1364
# the    1175
# na     1000
# ti      878
# al      832
# mi      765
# pa      712
# za      660
# si      608
# sad     604
# of      566

# %%
word_counts.loc['apsolutno', 'count']
# Out:
# 14

# %%
# General chat data

# Manually specify colors for each user
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']

plt.figure(figsize=(40, 20))
bars = plt.bar(top_words.index, top_words['count'],  color=colors[:len(top_words)])
plt.xlabel('Word', fontsize=30, labelpad=40)  # Increase font size and set label padding for x-axis label
plt.ylabel('Number of usages', fontsize=30, labelpad=50)  # Increase font size and set label padding for y-axis label
plt.title('Number of Times Each Word was sent', fontsize=40, pad=50)  # Increase font size and set title padding

# Increase font size for x-axis and y-axis ticks
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Add value annotations on top of the bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, bar.get_height() + 50, str(int(bar.get_height())),
             fontsize=20, color='black')

plt.show()

# %%
# For specific user


messages_certain_user = messages[messages['sender'] == 'Lobel Marunić']
print(messages_certain_user)

# Assuming you have a DataFrame named 'messages'
all_messages = ' '.join(messages_certain_user['contents'].astype(str).str.lower())

# Split the text into words
words = all_messages.split()

# Create a DataFrame with word counts
word_counts = pd.Series(words).value_counts().reset_index()
word_counts.columns = ['word', 'count']

word_counts.set_index('word', inplace=True)

word_counts = word_counts.drop(['omitted>', '<media', 'null', 'message'])

word_counts.reset_index()

# Display the top 20 most common words
top_words = word_counts.head(20)


# Manually specify colors for each user
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']


plt.figure(figsize=(40, 20))
bars = plt.bar(top_words.index, top_words['count'],  color=colors[:len(top_words)])
plt.xlabel('Word', fontsize=30, labelpad=40)  # Increase font size and set label padding for x-axis label
plt.ylabel('Number of usages', fontsize=30, labelpad=50)  # Increase font size and set label padding for y-axis label
plt.title('Number of Times Each Word was sent', fontsize=40, pad=50)  # Increase font size and set title padding

# Increase font size for x-axis and y-axis ticks
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Add value annotations on top of the bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, bar.get_height() + 50, str(int(bar.get_height())),
             fontsize=20, color='black')

plt.show()
# Out:
#                timestamp                            chat_name         sender  \
# 1792   29/10/2023, 22:42  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 1793   29/10/2023, 22:42  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 1794   29/10/2023, 22:42  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 1795   29/10/2023, 22:42  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 1800   29/10/2023, 22:45  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# ...                  ...                                  ...            ...
# 39977  10/12/2023, 23:17  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 39978  10/12/2023, 23:17  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 39979  10/12/2023, 23:17  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 39983  10/12/2023, 23:17  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
# 39986  10/12/2023, 23:17  WhatsApp Chat with Diplomacy 🗿🥸.txt  Lobel Marunić
#
#                                                 contents
# 1792                                           Naravno\n
# 1793                                        #girlpower\n
# 1794                                        #yougogirl\n
# 1795                           #strongindependentwoman\n
# 1800   Ali činjenica je da mi se čini da neki natjeca...
# ...                                                  ...
# 39977                   Kako bi bilo fora to napraviti\n
# 39978                                  Ali ček zapravo\n
# 39979                                         Znaš šta\n
# 39983          @385989024736 ajmo to napravit randomly\n
# 39986  Idem vidjet dal postoji neki Whatsapp API ili ...
#
# [616 rows x 4 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 19
#      15 word_counts.columns = ['word', 'count']
#      17 word_counts.set_index('word', inplace=True)
# ---> 19 word_counts = word_counts.drop(['omitted>', '<media', 'null', 'message'])
#      21 word_counts.reset_index()
#      23 # Display the top 20 most common words
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['null'] not found in axis"

# %%
# For specific user

messages_certain_user = messages

# Assuming you have a DataFrame named 'messages'
all_messages = ' '.join(messages_certain_user['contents'].astype(str).str.lower())

words = [word for word in all_messages.split() if len(word) >= 4]

# Create a DataFrame with word counts
word_counts = pd.Series(words).value_counts().reset_index()
word_counts.columns = ['word', 'count']

word_counts.set_index('word', inplace=True)

word_counts = word_counts.drop(['omitted>', '<media', 'null', 'message'])

word_counts.reset_index()

# Display the top 20 most common words
top_words = word_counts.head(40)


# Manually specify colors for each user
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']


plt.figure(figsize=(40, 20))
bars = plt.bar(top_words.index, top_words['count'],  color=colors[:len(top_words)])
plt.xlabel('Word', fontsize=30, labelpad=40)  # Increase font size and set label padding for x-axis label
plt.ylabel('Number of usages', fontsize=30, labelpad=50)  # Increase font size and set label padding for y-axis label
plt.title('Number of Times Each Word was sent', fontsize=40, pad=50)  # Increase font size and set title padding

# Increase font size for x-axis and y-axis ticks
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Add value annotations on top of the bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, bar.get_height() + 50, str(int(bar.get_height())),
             fontsize=20, color='black')

plt.show()
