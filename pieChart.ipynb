# %%
from tkinter import Tk
from tkinter import filedialog as fd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.cm import viridis

from functions import *

# %%
messages = process_transcript_to_pandas()

dates_dataframe = GenerateDateFrame(messages)

# %%
print(messages)
messages = messages.reset_index()
# Out:
#                timestamp                            chat_name  \
# 0      30/10/2023, 12:51  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 1      30/10/2023, 12:52  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 2      30/10/2023, 12:52  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 3      30/10/2023, 12:54  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 4      30/10/2023, 12:55  WhatsApp Chat with Diplomacy 🗿🥸.txt
# ...                  ...                                  ...
# 39979  17/12/2023, 22:03  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 39980  17/12/2023, 22:03  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 39981  17/12/2023, 22:03  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 39982  17/12/2023, 22:04  WhatsApp Chat with Diplomacy 🗿🥸.txt
# 39983  17/12/2023, 22:04  WhatsApp Chat with Diplomacy 🗿🥸.txt
#
#                           sender                          contents
# 0               Dominik Slovinac                 <Media omitted>\n
# 1               Dominik Slovinac                 <Media omitted>\n
# 2               Dominik Slovinac                 <Media omitted>\n
# 3                      Vito Pito                 <Media omitted>\n
# 4                          ryū h                          a must\n
# ...                          ...                               ...
# 39979  Filip (Ne Gašparović Lol)                    Što je to? 😭\n
# 39980           Glorija Pinturić                          Emesus\n
# 39981           Glorija Pinturić                      Emo+ Jesus\n
# 39982  Filip (Ne Gašparović Lol)  Znači Isus, ali je išao u mioc\n
# 39983           Glorija Pinturić                To bi bio Miosus\n
#
# [39984 rows x 4 columns]

# %%
user_message_counts = messages['sender'].value_counts().reset_index()
user_message_counts.columns = ['sender', 'message_count']
user_message_df = pd.DataFrame(user_message_counts)

print(user_message_df)
# Out:
#                        sender  message_count
# 0                      Zoe P.           6803
# 1                      Fran 7           6485
# 2            Dominik Slovinac           6441
# 3                       ryū h           4899
# 4                     Borna L           3919
# 5                        Gabi           3605
# 6            Glorija Pinturić           3085
# 7   Filip (Ne Gašparović Lol)           2151
# 8                   Vito Pito           1447
# 9               Lobel Marunić            765
# 10                     Roko V            384

# %%
# Manually specify colors for each user
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']

# %%
plt.figure(figsize=(40, 20))
bars = plt.bar(user_message_df['sender'], user_message_df['message_count'],  color=colors[:len(user_message_df)])
plt.xlabel('Osoba', fontsize=30, labelpad=40)  # Increase font size and set label padding for x-axis label
plt.ylabel('Broj poruka', fontsize=30, labelpad=50)  # Increase font size and set label padding for y-axis label
plt.title('Broj poruka svake osobe', fontsize=40, pad=50)  # Increase font size and set title padding

# Increase font size for x-axis and y-axis ticks
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Add value annotations on top of the bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, bar.get_height() + 50, str(int(bar.get_height())),
             fontsize=20, color='black')

plt.show()
